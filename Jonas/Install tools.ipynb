# %% [markdown]
# # Essentials

# %%
# %pip install pandas
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/61.0 kB ? eta -:--:--
#      -------------------------- ------------- 41.0/61.0 kB 1.9 MB/s eta 0:00:01
#      -------------------------- ------------- 41.0/61.0 kB 1.9 MB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 466.1 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB 1.9 MB/s eta 0:00:06
#    ---------------------------------------- 0.0/11.5 MB 1.9 MB/s eta 0:00:06
#     --------------------------------------- 0.2/11.5 MB 1.4 MB/s eta 0:00:09
#    - -------------------------------------- 0.4/11.5 MB 2.2 MB/s eta 0:00:06
#    - -------------------------------------- 0.5/11.5 MB 2.2 MB/s eta 0:00:05
#    -- ------------------------------------- 0.8/11.5 MB 2.7 MB/s eta 0:00:05
# ...

# %%
# %pip install numpy

# %%
# %pip install seaborn
# Out:
# ...
#      ---------------------------------------- 0.0/162.3 kB ? eta -:--:--
#      -------------------------- ----------- 112.6/162.3 kB 2.2 MB/s eta 0:00:01
#      -------------------------------------- 162.3/162.3 kB 2.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    -------- ------------------------------- 61.4/294.9 kB ? eta -:--:--
#    -------- ------------------------------- 61.4/294.9 kB ? eta -:--:--
#    ------------------- -------------------- 143.4/294.9 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 256.0/294.9 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 256.0/294.9 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#     --------------------------------------- 0.1/7.6 MB ? eta -:--:--
# ...
